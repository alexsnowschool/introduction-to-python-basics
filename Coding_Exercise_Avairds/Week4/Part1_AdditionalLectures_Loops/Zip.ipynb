# %% [markdown]
# <figure>
# <center>
# <img src='https://raw.githubusercontent.com/Alex-Snow-School-Lab/Python-Basics/master/cover%20ppt.png' width = '800px'/>
# </center>
# </figure>

# %%
# Exercise 1
list1 = [1, 2, 3, 4, 5]
list2  = ['one', 'two', 'three', 'four', 'five']

zipped = list(zip(list1, list2, items))
print(zipped)

# How to unzip --> use * 
unzipped = list(zip(*zipped))
print(unzipped)
# Out:
# [(1, 'one', 'Apple'), (2, 'two', 'Banana'), (3, 'three', 'Orange')]
# [(1, 2, 3), ('one', 'two', 'three'), ('Apple', 'Banana', 'Orange')]

# %%
# Exercise - 2
items = ['Apple', 'Banana', 'Orange']
counts = [3, 6, 4]
prices = [0.99, 0.25, 0.50]

sentences = []
for (item, count, price) in zip (items, counts, prices):
	item, count, price = str(item), str(count), str(price)
	sentence = "I bought " + count + ' ' + item + 's at' + price + ' cents each.'
	sentences.append(sentence)
 
print(sentence)
# Out:
# I bought 4 Orange s at0.5 cents each.
